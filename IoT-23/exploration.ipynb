# %%
import pandas as pd

# %%
path = "data/CTU-Honeypot-Capture-4-1/bro/preprocessed.csv"

# %%
df = pd.read_csv(path, sep='\t')

# %%
df
# Out:
#                ts                 uid      id.orig_h  id.orig_p  \
# 0    1.540469e+09  CGm6jB4dXK71ZDWUDh  192.168.1.132      58687
# 1    1.540469e+09  CnaDAG3n5r8eiG4su2  192.168.1.132       1900
# 2    1.540469e+09  CUrxU238nt0m6yTgKf  192.168.1.132      32893
# 3    1.540470e+09  CGQf8t1kjdxB5PHXL4  192.168.1.132      53395
# 4    1.540470e+09  CUo9DH2QDnCaBIGjkg  192.168.1.132      52801
# ..            ...                 ...            ...        ...
# 447  1.540547e+09  CaITg437HfJAXTXZ44  192.168.1.132      53722
# 448  1.540547e+09  ChD10Y1fVGrFvMpD6g  192.168.1.132      43799
# 449  1.540548e+09  Caxyou4MZpRXfDBG8h  192.168.1.132      51285
# 450  1.540469e+09   CkHQfG3B034MyvP3W  192.168.1.132      37653
# 451  1.540478e+09  ClZeN63S7LbgEs2ZNk  192.168.1.132       1900
#
#            id.resp_h  id.resp_p proto service      duration orig_bytes  ...  \
# 0       216.239.35.4        123   udp       -      0.114184         48  ...
# ...
