# %%
import pandas as pd

# %%
d1_path = 'data/Ecobee_Thermostat/'

# %%
df = pd.read_csv(d1_path + 'benign_traffic.csv')

# %%
df
# Out:
#        MI_dir_L5_weight  MI_dir_L5_mean  MI_dir_L5_variance  MI_dir_L3_weight  \
# 0              1.000000       60.000000            0.000000          1.000000
# 1              1.000000      110.000000            0.000000          1.000000
# 2              1.724055       91.439104          249.441812          1.823878
# 3              1.000000      342.000000            0.000000          1.000000
# 4              2.516815       90.867308          150.827639          2.688981
# ...                 ...             ...                 ...               ...
# 13108          1.021632       72.648557         2043.443501          1.100243
# 13109          1.000000       60.000003            0.000586          1.000123
# 13110          1.000000      110.000000            0.000000          1.000000
# 13111          1.000000      380.000000            0.000000          1.000000
# 13112          1.364540      149.885838        19303.319310          1.545817
#
# ...

# %%
df_mirai_ack = pd.read_csv(d1_path + 'mirai_attacks/ack.csv')

# %%
df_mirai_ack
# Out:
#         MI_dir_L5_weight  MI_dir_L5_mean  MI_dir_L5_variance  \
# 0               1.000000      566.000000        0.000000e+00
# 1               1.996582      566.000000        0.000000e+00
# 2               2.969101      566.000000        5.820766e-11
# 3               3.939044      566.000000        5.820766e-11
# 4               4.917028      566.000000        1.164153e-10
# ...                  ...             ...                 ...
# 113280        173.619105      437.422636        4.852270e+04
# 113281        174.618532      438.158969        4.833896e+04
# 113282        175.617377      438.886921        4.815624e+04
# 113283        176.614910      439.606640        4.797454e+04
# 113284        176.577445      440.322436        4.779281e+04
#
#         MI_dir_L3_weight  MI_dir_L3_mean  MI_dir_L3_variance  \
# 0               1.000000      566.000000        0.000000e+00
# 1               1.997948      566.000000        5.820766e-11
# ...

# %%
d2_path = 'data/Danmini_Doorbell/'

# %%
df = pd.read_csv(d2_path + 'gafgyt_attacks/scan.csv')

# %%
df
# Out:
#        MI_dir_L5_weight  MI_dir_L5_mean  MI_dir_L5_variance  MI_dir_L3_weight  \
# 0              1.000000       98.000000        0.000000e+00          1.000000
# 1              1.027124       98.000000        1.818989e-12          1.114820
# 2              1.029968       98.000000        0.000000e+00          1.133728
# 3              1.338152       74.086423        1.933753e+02          1.581141
# 4              2.311785       74.049039        1.097295e+02          2.562374
# ...                 ...             ...                 ...               ...
# 29844         11.939673       74.732911        2.567225e+02         27.065793
# 29845         12.939348       74.676269        2.369203e+02         28.065350
# 29846         13.939166       74.627753        2.199541e+02         29.065113
# 29847         14.257001       74.583722        2.045520e+02         29.203117
# 29848         15.256553       74.545462        1.911653e+02         30.202567
#
# ...
