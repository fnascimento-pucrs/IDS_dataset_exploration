# %%
import pandas as pd

# %%
path = "data/IoT Intrusion Dataset 2020.csv"

# %%
df = pd.read_csv(path)

# %%
df['Src_IP'].value_counts()
# Out:
# 192.168.0.13       222096
# 192.168.0.16       125890
# 192.168.0.24       122846
# 104.118.134.215     46092
# 104.74.213.186      23308
#                     ...
# 222.7.154.50            1
# 222.75.123.230          1
# 111.167.71.201          1
# 222.145.101.14          1
# 222.79.10.127           1
# Name: Src_IP, Length: 57985, dtype: int64

# %%
df['Src_IP'].value_counts()[:30].plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
df['Dst_IP'].value_counts()
# Out:
# 192.168.0.13       164532
# 192.168.0.16       143150
# 210.89.164.90      131170
# 192.168.0.24        85813
# 222.239.240.107     11240
#                     ...
# 121.254.133.161         1
# 52.221.48.93            1
# 121.254.133.163         1
# 52.3.44.80              1
# 222.248.174.186         1
# Name: Dst_IP, Length: 478, dtype: int64

# %%
df['Dst_IP'].value_counts()[:30].plot(kind="bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Local addresses

# %%
df[df['Src_IP'].str.startswith('192.168.')]['Src_IP'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df[df['Dst_IP'].str.startswith('192.168.')]['Dst_IP'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>
